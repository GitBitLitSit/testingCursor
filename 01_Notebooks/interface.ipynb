# %% [markdown]
# ### Cable Corridor Computation

# %%
# ignore the nopython dependency warning, as it cant be fixed with current dependencies
import warnings

warnings.filterwarnings("ignore", message=".*The 'nopython' keyword.*")

# Package Imports
import pandas as pd
import geopandas as gpd
from shapely.geometry import LineString, Polygon, Point
import pickle

# Importing my modules
from src.main import global_vars
from src.main.classes_geometry_objects import LineString_3D, Point_3D
from src.main import optimization_execution
from src.main import geometry_utilities, mechanical_computations
import src.main.interface

# Interface modules
from ipywidgets import VBox, HBox
from src.main.interface import interactive_cr_selection

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# Instructions for usage:
#
# 1. Load the libraries above
# 2. Execute the cells in "Load Resources" - this will take several minutes
# 3. Run the Interface in "Plotting"

# %% [markdown]
# #### Preprocessing Archive

# %%
# # Load, preprocess and save the dataframe with the corresponding number - only needed to do once
# data_loading.load_and_preprocess_raw_data(data_to_load=3)
# tree_gdf, height_gdf = data_loading.load_processed_gdfs(data_to_load=3)
# # create coordinates for each dataframe with the corresponding upper and lower anchors
# coords = []
# fig, ax = plt.subplots()
# ax.set_xlabel("X coordinate", fontsize=15)
# ax.set_ylabel("Y coordinate", fontsize=15)
# ax.scatter(tree_gdf["x"], tree_gdf["y"])

# cid = fig.canvas.mpl_connect(
#     "button_press_event", lambda event: plotting_2d.onclick(event, coords)
# )

# from src.main import classes_cable_road_computation
# from importlib import reload

# reload(classes_cable_road_computation)

# from src.main import classes_cable_road_computation
# import types


# from src.main.cable_road_computation_main import cable_road_computation
# from src.main import cable_road_computation

# forest_area_3.compute_cable_road = types.MethodType(
#     classes_cable_road_computation.forest_area.compute_cable_road, forest_area_3
# )

# from src.main.classes_geometry_objects import LineString_3D, Point_3D
# from src.main import geometry_utilities, mechanical_computations

# cable_road_object = forest_area_3.line_gdf.iloc[0]["Cable Road Object"]

# loaded_index = len(cable_road_object.points_along_line) // 2

# # get the centroid, lines and angles of the two CRs, once tensioned, once empty
# line_centroid_loaded_cr = (
#     mechanical_computations.get_line_3d_from_cr_startpoint_to_centroid(
#         cable_road_object,
#         move_towards_start_point=False,
#         sloped=True,
#         index=loaded_index,
#     )
# )


# def compute_line_from_top_to_bottom(support_object):
#     xy_point = support_object.xy_location
#     xy_floor = support_object.floor_height
#     xy_height = support_object.total_height

#     # piece together the triple from the xy coordinates and the z (height)
#     start_point_xyz = (
#         xy_point.coords[0][0],
#         xy_point.coords[0][1],
#         xy_height,
#     )
#     end_point_xyz = (
#         xy_point.coords[0][0],
#         xy_point.coords[0][1],
#         xy_floor,
#     )

#     end_point_xyz = Point_3D(*end_point_xyz)
#     start_point_xyz = Point_3D(*start_point_xyz)

#     return LineString_3D(start_point_xyz, end_point_xyz)


# line_support_from_bottom_to_top = compute_line_from_top_to_bottom(
#     cable_road_object.start_support
# )

# angle_between_support_cr = geometry_utilities.angle_between_3d_lines(
#     line_centroid_loaded_cr, line_support_from_bottom_to_top
# )

# print(angle_between_support_cr)

# # print the coordinates of the centroid and the support lines
# print(line_centroid_loaded_cr.start_point.xyz)
# print(line_support_from_bottom_to_top.end_point.xyz)

# # store forest_area_3
# output = open("forest_area_3_10_2024.pkl", "wb")
# pickle.dump(forest_area_3, output)

# # # new forest area as of march
# # output = open("forest_area_3_03_2024.pkl", "wb")
# # pickle.dump(forest_area_3, output)

# # from src.main import classes_cable_road_computation

# # create a class instance of the forest area with all the necessary attributes
# forest_area_3_25_04_2024 = classes_cable_road_computation.forest_area(
#     forest_area_3.tree_gdf, forest_area_3.height_gdf, extra_geometry_gpd
# )

# # store optimization_results
# output = open("optimization_results_10_2024.pkl", "wb")
# pickle.dump(optimization_results, output, protocol=4)

# # load the optimization_results
# pkl_file = open("optimization_results.pkl", "rb")
# optimization_results = pickle.load(pkl_file)
# results_df, optimization_result_list, model_list = optimization_results

# # and the forest_area_3
# pkl_file = open("forest_area_3.pkl", "rb")
# forest_area_3 = pickle.load(pkl_file)

# output = open("forest_area_3_10_2024.pkl", "wb")
# pickle.dump(forest_area_3, output)

# %% [markdown]
# #### Load Resources

# %%
# # load the optimization_results
pkl_file = open("optimization_results_10_2024.pkl", "rb")
optimization_results = pickle.load(pkl_file)
results_df, optimization_result_list, model_list = optimization_results

# and the forest_area_3
pkl_file = open("forest_area_3_05_2024.pkl", "rb")
forest_area_3 = pickle.load(pkl_file)

# forest_area_3.compute_line_costs()
kdtree = global_vars.init(forest_area_3.height_gdf)

# %%
# manually insert those coordinates
# recorded coordinates for the given areas


def compute_geometry():
    downhill_anchors = Polygon(
        [
            Point(xy)
            for xy in [
                (-123.88268627035482, 83.05479790035122),
                (-74.89307684787903, 138.5299549848453),
                (-21.10056454084676, 161.97821725767267),
                (-6.051468835903222, 148.2524051955298),
                (-60.16417466857257, 116.79741921978575),
                (-115.23746107815322, 64.75371515082742),
            ]
        ]
    )
    uphill_anchors = Polygon(
        [
            Point(xy)
            for xy in [
                (-55.04107825837903, -15.31352187833928),
                (-17.578435758838708, -17.601157222029755),
                (4.194723984483858, -1.5877098161964227),
                (30.450593086725803, -30.18315161232738),
                (-11.49475877173387, -41.04941949485714),
                (-58.5632070403871, -38.189875315244045),
            ]
        ]
    )
    # road = LineString([(-57.282432937838706, -17.029248386107135), (-34.86888614324194, -21.604519073488092), (-15.337081079379033, -15.31352187833928), (-0.2879853744354932, -7.878707011345227), (12.51975565104837, 6.990922722642864), (19.884206740701615, 21.86055245663097)])
    # road = LineString([(-59.52378761729838, -12.453977698726185), (-41.91314370725806, -13.597795370571419), (-18.218822810112897, -10.16634235503571), (3.2341434075725886, 0.12801669157144602), (15.401497381782264, 23.576278964398824), (17.00246500996775, 26.43582314401192)])
    road = LineString(
        [
            (-89.6286010742188, -24.4624996185303),
            (-69.618896484375, -20.364200592041),
            (-41.314998626709, -13.9251003265381),
            (-29.2644004821777, -8.47910022735596),
            (-20.2950000762939, -3.67030000686646),
            (-15.375, -0.148599997162819),
            (-6.49030017852783, 2.74860000610352),
            (0.943400025367737, 3.86450004577637),
            (15.1605997085571, -0.302300006151199),
            (29.3377990722656, -3.47709989547729),
        ]
    )

    inner_forest = Polygon(
        [
            Point(xy)
            for xy in [
                (-105.43005197808363, 62.73802056488026),
                (-10.557896233758669, 146.34023494632802),
                (13.160142702322588, 51.07259530235265),
                (8.890895693827957, 9.27148811162877),
                (-55.62217021231302, -10.17088732591722),
                (-81.71201304200238, 18.992675830401765),
            ]
        ]
    )

    extra_geometry_gpd = gpd.GeoDataFrame(
        pd.DataFrame(
            {
                "name": ["uphill_anchors", "road", "downhill_anchors", "inner_forest"],
                "geometry": [uphill_anchors, road, downhill_anchors, inner_forest],
            }
        )
    )

    # set the name as index to easily select the geometry
    extra_geometry_gpd.set_index("name", inplace=True)
    extra_geometry_gpd.loc["road"]

    return extra_geometry_gpd


extra_geometry_gpd = compute_geometry()


def compute_line_from_top_to_bottom(support_object):
    xy_point = support_object.xy_location
    xy_floor = support_object.floor_height
    xy_height = support_object.total_height

    # piece together the triple from the xy coordinates and the z (height)
    start_point_xyz = (
        xy_point.coords[0][0],
        xy_point.coords[0][1],
        xy_height,
    )
    end_point_xyz = (
        xy_point.coords[0][0],
        xy_point.coords[0][1],
        xy_floor,
    )

    end_point_xyz = Point_3D(*end_point_xyz)
    start_point_xyz = Point_3D(*start_point_xyz)

    return LineString_3D(start_point_xyz, end_point_xyz)


def compute_angle_between_support_and_cr(line_gdf, support_type):
    for index, row in line_gdf.iterrows():
        cable_road_object = row["Cable Road Object"]
        loaded_index = len(cable_road_object.points_along_line) // 2

        line_centroid_loaded_cr = (
            mechanical_computations.get_line_3d_from_cr_startpoint_to_centroid(
                cable_road_object,
                move_towards_start_point=False if support_type == "start" else True,
                sloped=True,
                index=loaded_index,
            )
        )

        support_object = getattr(cable_road_object, f"{support_type}_support")
        line_support_from_bottom_to_top = compute_line_from_top_to_bottom(
            support_object
        )

        angle_between_support_cr = geometry_utilities.angle_between_3d_lines(
            line_centroid_loaded_cr, line_support_from_bottom_to_top
        )

        line_gdf.loc[index, f"angle_between_{support_type}_support_and_cr"] = (
            angle_between_support_cr
        )

    return line_gdf


def compute_angles_between_supports_and_cr(line_gdf):
    line_gdf = compute_angle_between_support_and_cr(line_gdf, "start")
    line_gdf = compute_angle_between_support_and_cr(line_gdf, "end")
    return line_gdf


def compute_cable_corridors(forest_area_3):
    # # and the forest_area_3
    # pkl_file = open("forest_area_3_05_2024.pkl", "rb")
    # forest_area_3 = pickle.load(pkl_file)

    # Readjusting the mdm computation and the corresponding euler knicklastforces
    # forest_area_3 = forest_area_3_25_04_2024

    forest_area_3.tree_gdf["middle_height"] = forest_area_3.tree_gdf[
        "diameter_series"
    ].apply(lambda x: len(x) // 2)
    # and the corresponding diameter there
    forest_area_3.tree_gdf["mdm"] = forest_area_3.tree_gdf.apply(
        lambda x: x["diameter_series"][x["middle_height"]], axis=1
    )

    # get the euler forces
    list_of_euler_max_force_lists = []
    for index, row in forest_area_3.tree_gdf.iterrows():
        temp_list = [
            mechanical_computations.euler_knicklast(row["mdm"], height * 2)
            for height in row["height_series"]
        ]
        list_of_euler_max_force_lists.append(temp_list)

    forest_area_3.tree_gdf["max_supported_force_series"] = list_of_euler_max_force_lists

    forest_area_3.compute_cable_road()

    forest_area_3.line_gdf = compute_angles_between_supports_and_cr(
        forest_area_3.line_gdf
    )

    forest_area_3.compute_line_costs()

    return forest_area_3


forest_area_3 = compute_cable_corridors(forest_area_3)


def optimization_main_loop(forest_area_gdf):
    """Main loop for the optimization algorithm"""

    optimization_result_list = []
    model_list = []

    # first the basis optimization
    print("Starting basis optimization")
    (
        model_list,
        optimization_result_list,
    ) = optimization_execution.soo_optimization_augmecon(
        model_list, optimization_result_list, forest_area_gdf
    )

    # then the manual weights optimization
    print("Starting manual weights optimization")
    optimization_result_list = optimization_execution.soo_optimization_manual_weights(
        model_list, optimization_result_list, forest_area_gdf
    )

    # then the NSGA II optimization
    print("Starting NSGA II optimization")
    optimization_result_list = optimization_execution.nsga_optimization(
        model_list, optimization_result_list, forest_area_gdf
    )

    # create a result df to save the results
    results_df = optimization_execution.create_results_df(
        optimization_result_list, model_list[0], forest_area_gdf
    )

    # # create ranges for the different objectives based on the results
    # (
    #     ecological_range,
    #     ecological_step,
    #     ergonomics_range,
    #     ergonomics_step,
    # ) = optimization_execution.compute_augmecon_ranges(results_df)

    # # conduct the augmecon optimization
    # print("Starting augmecon optimization")
    # optimization_result_list = optimization_execution.augmecon_optimization(
    #     optimization_result_list,
    #     ecological_range,
    #     ecological_step,
    #     ergonomics_range,
    #     ergonomics_step,
    #     forest_area_gdf,
    # )

    # and finally the expert layout optimization
    # print("Starting expert layout optimization")
    # optimization_result_list = optimization_execution.expert_layout_optimization(
    #     optimization_result_list, model_list[0], forest_area_gdf
    # )

    # and final result list
    results_df = optimization_execution.create_results_df(
        optimization_result_list, model_list[0], forest_area_gdf
    )

    return results_df, optimization_result_list, model_list


results_df, optimization_result_list, model_list = optimization_main_loop(forest_area_3)

optimization_results = [results_df, optimization_result_list, model_list]
# Out:
# c:\alles\uni\2025SS\BachelorArbeit\codexBachi\.venv\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning:
#
# The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
# loaded new
# c:\alles\uni\2025SS\BachelorArbeit\codexBachi\.venv\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning:
#
# The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
# 2304  candidates initially
# 2278  after slope deviations
# 961  after supports trees
# c:\alles\uni\2025SS\BachelorArbeit\codexBachi\.venv\lib\site-packages\pandas\core\dtypes\cast.py:122: ShapelyDeprecationWarning:
#
# The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
# 38  after possible anchor triples
# Tension to begin with is 85000.0
# checking if tower and anchor trees hold
# exerted force 85000.0
# did not find anchor tree that holds - iterating
# exerted force 85000.0
# did not find anchor tree that holds - iterating
# exerted force 85000.0
# found anchor tree that holds
# Tower and anchors hold: True
# After the iterative process it is now 85000.0
# checking if no collisions overall line
# Found no collisions
# Tension to begin with is 85000.0
# checking if tower and anchor trees hold
# exerted force 85000.0
# did not find anchor tree that holds - iterating
# exerted force 85000.0
# did not find anchor tree that holds - iterating
# exerted force 85000.0
# found anchor tree that holds
# Tower and anchors hold: True
# After the iterative process it is now 85000.0
# checking if no collisions overall line
# Found collisions
# Need to find supports
# Setting up support candidates
# raising height to  6
# checking if support withstands tension
# force on support left 6580.8029568842085
# force on support right 5514.632772964918
# max supported force 105010.14792787982
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  7
# checking if support withstands tension
# force on support left 12535.064091543376
# force on support right 10981.342380833747
# max supported force 77150.31276334028
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  8
# checking if support withstands tension
# force on support left 16899.631807886963
# force on support right 14785.216871659937
# max supported force 59068.2082094324
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: True
# found viable sub-config
# Tension to begin with is 85000.0
# checking if tower and anchor trees hold
# exerted force 85000.0
# did not find anchor tree that holds - iterating
# exerted force 85000.0
# did not find anchor tree that holds - iterating
# exerted force 85000.0
# found anchor tree that holds
# Tower and anchors hold: True
# After the iterative process it is now 85000.0
# checking if no collisions overall line
# Found no collisions
# Tension to begin with is 85000.0
# checking if tower and anchor trees hold
# exerted force 85000.0
# did not find anchor tree that holds - iterating
# exerted force 85000.0
# did not find anchor tree that holds - iterating
# exerted force 85000.0
# found anchor tree that holds
# Tower and anchors hold: True
# After the iterative process it is now 85000.0
# checking if no collisions overall line
# Found no collisions
# Tension to begin with is 85000.0
# checking if tower and anchor trees hold
# exerted force 85000.0
# did not find anchor tree that holds - iterating
# exerted force 85000.0
# did not find anchor tree that holds - iterating
# exerted force 85000.0
# found anchor tree that holds
# Tower and anchors hold: True
# After the iterative process it is now 85000.0
# checking if no collisions overall line
# Found no collisions
# Tension to begin with is 85000.0
# checking if tower and anchor trees hold
# exerted force 85000.0
# did not find anchor tree that holds - iterating
# exerted force 85000.0
# did not find anchor tree that holds - iterating
# exerted force 85000.0
# found anchor tree that holds
# Tower and anchors hold: True
# After the iterative process it is now 85000.0
# checking if no collisions overall line
# Found no collisions
# Tension to begin with is 85000.0
# checking if tower and anchor trees hold
# exerted force 85000.0
# did not find anchor tree that holds - iterating
# exerted force 85000.0
# did not find anchor tree that holds - iterating
# exerted force 85000.0
# found anchor tree that holds
# Tower and anchors hold: True
# After the iterative process it is now 85000.0
# checking if no collisions overall line
# Found no collisions
# Tension to begin with is 85000.0
# checking if tower and anchor trees hold
# exerted force 85000.0
# did not find anchor tree that holds - iterating
# exerted force 85000.0
# did not find anchor tree that holds - iterating
# exerted force 85000.0
# found anchor tree that holds
# Tower and anchors hold: True
# After the iterative process it is now 85000.0
# checking if no collisions overall line
# Found no collisions
# Tension to begin with is 85000.0
# checking if tower and anchor trees hold
# exerted force 85000.0
# did not find anchor tree that holds - iterating
# exerted force 85000.0
# found anchor tree that holds
# Tower and anchors hold: True
# After the iterative process it is now 85000.0
# checking if no collisions overall line
# Found no collisions
# Tension to begin with is 85000.0
# checking if tower and anchor trees hold
# exerted force 85000.0
# did not find anchor tree that holds - iterating
# exerted force 85000.0
# did not find anchor tree that holds - iterating
# exerted force 85000.0
# did not find anchor tree that holds - iterating
# Tower and anchors hold: False
# checking if tower and anchor trees hold
# exerted force 75000.0
# did not find anchor tree that holds - iterating
# exerted force 75000.0
# did not find anchor tree that holds - iterating
# exerted force 75000.0
# did not find anchor tree that holds - iterating
# Tower and anchors hold: False
# checking if tower and anchor trees hold
# exerted force 65000.0
# did not find anchor tree that holds - iterating
# exerted force 65000.0
# did not find anchor tree that holds - iterating
# exerted force 65000.0
# did not find anchor tree that holds - iterating
# Tower and anchors hold: False
# checking if tower and anchor trees hold
# exerted force 55000.0
# found anchor tree that holds
# Tower and anchors hold: True
# After the iterative process it is now 55000.0
# checking if no collisions overall line
# Found collisions
# Need to find supports
# Setting up support candidates
# raising height to  6
# checking if support withstands tension
# force on support left 8837.881646276912
# force on support right 7311.689007986014
# max supported force 339571.2084915763
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: True
# found viable sub-config
# Tension to begin with is 85000.0
# checking if tower and anchor trees hold
# exerted force 85000.0
# did not find anchor tree that holds - iterating
# exerted force 85000.0
# did not find anchor tree that holds - iterating
# exerted force 85000.0
# did not find anchor tree that holds - iterating
# Tower and anchors hold: False
# checking if tower and anchor trees hold
# exerted force 75000.0
# did not find anchor tree that holds - iterating
# exerted force 75000.0
# did not find anchor tree that holds - iterating
# exerted force 75000.0
# did not find anchor tree that holds - iterating
# Tower and anchors hold: False
# checking if tower and anchor trees hold
# exerted force 65000.0
# did not find anchor tree that holds - iterating
# exerted force 65000.0
# did not find anchor tree that holds - iterating
# exerted force 65000.0
# did not find anchor tree that holds - iterating
# Tower and anchors hold: False
# checking if tower and anchor trees hold
# exerted force 55000.0
# found anchor tree that holds
# Tower and anchors hold: True
# After the iterative process it is now 55000.0
# checking if no collisions overall line
# Found collisions
# Need to find supports
# Setting up support candidates
# raising height to  6
# checking if support withstands tension
# force on support left 8663.569353201965
# force on support right 7219.874522504844
# max supported force 339571.2084915763
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: True
# found viable sub-config
# Tension to begin with is 85000.0
# checking if tower and anchor trees hold
# exerted force 85000.0
# did not find anchor tree that holds - iterating
# exerted force 85000.0
# did not find anchor tree that holds - iterating
# exerted force 85000.0
# did not find anchor tree that holds - iterating
# Tower and anchors hold: False
# checking if tower and anchor trees hold
# exerted force 75000.0
# did not find anchor tree that holds - iterating
# exerted force 75000.0
# did not find anchor tree that holds - iterating
# exerted force 75000.0
# did not find anchor tree that holds - iterating
# Tower and anchors hold: False
# checking if tower and anchor trees hold
# exerted force 65000.0
# did not find anchor tree that holds - iterating
# exerted force 65000.0
# did not find anchor tree that holds - iterating
# exerted force 65000.0
# did not find anchor tree that holds - iterating
# Tower and anchors hold: False
# checking if tower and anchor trees hold
# exerted force 55000.0
# found anchor tree that holds
# Tower and anchors hold: True
# After the iterative process it is now 55000.0
# checking if no collisions overall line
# Found collisions
# Need to find supports
# Setting up support candidates
# raising height to  6
# checking if support withstands tension
# force on support left 8837.881646276912
# force on support right 7311.689007986014
# max supported force 339571.2084915763
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: True
# found viable sub-config
# Tension to begin with is 85000.0
# checking if tower and anchor trees hold
# exerted force 85000.0
# did not find anchor tree that holds - iterating
# exerted force 85000.0
# did not find anchor tree that holds - iterating
# exerted force 85000.0
# did not find anchor tree that holds - iterating
# Tower and anchors hold: False
# checking if tower and anchor trees hold
# exerted force 75000.0
# did not find anchor tree that holds - iterating
# exerted force 75000.0
# did not find anchor tree that holds - iterating
# exerted force 75000.0
# did not find anchor tree that holds - iterating
# Tower and anchors hold: False
# checking if tower and anchor trees hold
# exerted force 65000.0
# did not find anchor tree that holds - iterating
# exerted force 65000.0
# did not find anchor tree that holds - iterating
# exerted force 65000.0
# did not find anchor tree that holds - iterating
# Tower and anchors hold: False
# checking if tower and anchor trees hold
# exerted force 55000.0
# found anchor tree that holds
# Tower and anchors hold: True
# After the iterative process it is now 55000.0
# checking if no collisions overall line
# Found no collisions
# Tension to begin with is 85000.0
# checking if tower and anchor trees hold
# exerted force 85000.0
# did not find anchor tree that holds - iterating
# exerted force 85000.0
# did not find anchor tree that holds - iterating
# exerted force 85000.0
# did not find anchor tree that holds - iterating
# Tower and anchors hold: False
# checking if tower and anchor trees hold
# exerted force 75000.0
# did not find anchor tree that holds - iterating
# exerted force 75000.0
# did not find anchor tree that holds - iterating
# exerted force 75000.0
# did not find anchor tree that holds - iterating
# Tower and anchors hold: False
# checking if tower and anchor trees hold
# exerted force 65000.0
# did not find anchor tree that holds - iterating
# exerted force 65000.0
# did not find anchor tree that holds - iterating
# exerted force 65000.0
# did not find anchor tree that holds - iterating
# Tower and anchors hold: False
# checking if tower and anchor trees hold
# exerted force 55000.0
# did not find anchor tree that holds - iterating
# exerted force 55000.0
# did not find anchor tree that holds - iterating
# exerted force 55000.0
# did not find anchor tree that holds - iterating
# Tower and anchors hold: False
# checking if tower and anchor trees hold
# exerted force 45000.0
# did not find anchor tree that holds - iterating
# exerted force 45000.0
# found anchor tree that holds
# Tower and anchors hold: True
# After the iterative process it is now 45000.0
# checking if no collisions overall line
# Found collisions
# Need to find supports
# Setting up support candidates
# raising height to  6
# checking if support withstands tension
# force on support left 6255.2677014061155
# force on support right 6880.000469340095
# max supported force 31824.469715144893
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  7
# checking if support withstands tension
# force on support left 2081.8302351351185
# force on support right 2053.3072481716727
# max supported force 23381.243056024818
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  8
# checking if support withstands tension
# force on support left 5035.288637842191
# force on support right 3259.1109199666657
# max supported force 17901.264214769002
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  9
# checking if support withstands tension
# force on support left 9125.414406600956
# force on support right 6255.6103595090535
# max supported force 14144.208762286618
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  10
# checking if support withstands tension
# force on support left 12977.101373465279
# force on support right 9392.2656182099
# max supported force 11456.809097452162
# Support withstands tension: False
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# segment is infesible
# raising height to  6
# checking if support withstands tension
# force on support left 8979.251130290697
# force on support right 7306.358379228695
# max supported force 339571.2084915763
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  7
# checking if support withstands tension
# force on support left 13459.705083125868
# force on support right 11098.283898582178
# max supported force 249480.88787136218
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  8
# checking if support withstands tension
# force on support left 16888.569541515637
# force on support right 13877.0029540711
# max supported force 191008.80477651168
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: True
# found viable sub-config
# Tension to begin with is 85000.0
# checking if tower and anchor trees hold
# exerted force 85000.0
# did not find anchor tree that holds - iterating
# exerted force 85000.0
# did not find anchor tree that holds - iterating
# exerted force 85000.0
# did not find anchor tree that holds - iterating
# Tower and anchors hold: False
# checking if tower and anchor trees hold
# exerted force 75000.0
# did not find anchor tree that holds - iterating
# exerted force 75000.0
# did not find anchor tree that holds - iterating
# exerted force 75000.0
# did not find anchor tree that holds - iterating
# Tower and anchors hold: False
# checking if tower and anchor trees hold
# exerted force 65000.0
# did not find anchor tree that holds - iterating
# exerted force 65000.0
# did not find anchor tree that holds - iterating
# exerted force 65000.0
# did not find anchor tree that holds - iterating
# Tower and anchors hold: False
# checking if tower and anchor trees hold
# exerted force 55000.0
# did not find anchor tree that holds - iterating
# exerted force 55000.0
# did not find anchor tree that holds - iterating
# exerted force 55000.0
# did not find anchor tree that holds - iterating
# Tower and anchors hold: False
# checking if tower and anchor trees hold
# exerted force 45000.0
# did not find anchor tree that holds - iterating
# exerted force 45000.0
# found anchor tree that holds
# Tower and anchors hold: True
# After the iterative process it is now 45000.0
# checking if no collisions overall line
# Found collisions
# Need to find supports
# Setting up support candidates
# raising height to  6
# checking if support withstands tension
# force on support left 6255.2677014061155
# force on support right 6880.000469340095
# max supported force 31824.469715144893
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  7
# checking if support withstands tension
# force on support left 2081.8302351351185
# force on support right 2053.3072481716727
# max supported force 23381.243056024818
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  8
# checking if support withstands tension
# force on support left 5035.288637842191
# force on support right 3259.1109199666657
# max supported force 17901.264214769002
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  9
# checking if support withstands tension
# force on support left 9125.414406600956
# force on support right 6255.6103595090535
# max supported force 14144.208762286618
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  10
# checking if support withstands tension
# force on support left 12977.101373465279
# force on support right 9392.2656182099
# max supported force 11456.809097452162
# Support withstands tension: False
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# segment is infesible
# raising height to  6
# checking if support withstands tension
# force on support left 8979.251130290697
# force on support right 7306.358379228695
# max supported force 339571.2084915763
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  7
# checking if support withstands tension
# force on support left 13459.705083125868
# force on support right 11098.283898582178
# max supported force 249480.88787136218
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  8
# checking if support withstands tension
# force on support left 16888.569541515637
# force on support right 13877.0029540711
# max supported force 191008.80477651168
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: True
# found viable sub-config
# Tension to begin with is 85000.0
# checking if tower and anchor trees hold
# exerted force 85000.0
# did not find anchor tree that holds - iterating
# exerted force 85000.0
# did not find anchor tree that holds - iterating
# exerted force 85000.0
# did not find anchor tree that holds - iterating
# Tower and anchors hold: False
# checking if tower and anchor trees hold
# exerted force 75000.0
# did not find anchor tree that holds - iterating
# exerted force 75000.0
# did not find anchor tree that holds - iterating
# exerted force 75000.0
# did not find anchor tree that holds - iterating
# Tower and anchors hold: False
# checking if tower and anchor trees hold
# exerted force 65000.0
# did not find anchor tree that holds - iterating
# exerted force 65000.0
# did not find anchor tree that holds - iterating
# exerted force 65000.0
# did not find anchor tree that holds - iterating
# Tower and anchors hold: False
# checking if tower and anchor trees hold
# exerted force 55000.0
# found anchor tree that holds
# Tower and anchors hold: True
# After the iterative process it is now 55000.0
# checking if no collisions overall line
# Found collisions
# Need to find supports
# Setting up support candidates
# raising height to  6
# checking if support withstands tension
# force on support left 11288.993823136094
# force on support right 11578.572092391056
# max supported force 87076.46126575542
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  7
# checking if support withstands tension
# force on support left 6209.503435367921
# force on support right 5881.664523145088
# max supported force 63974.54297075909
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  8
# checking if support withstands tension
# force on support left 5138.911353855009
# force on support right 4619.118622195463
# max supported force 48980.50946198743
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  9
# checking if support withstands tension
# force on support left 7964.836923459211
# force on support right 5653.259674158442
# max supported force 38700.64945144686
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  10
# checking if support withstands tension
# force on support left 11797.87784422566
# force on support right 8090.797237684704
# max supported force 31347.526055671955
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  11
# checking if support withstands tension
# force on support left 15618.977204784205
# force on support right 10976.484914361083
# max supported force 25907.046327001615
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  12
# checking if support withstands tension
# force on support left 19219.52146626368
# force on support right 13977.433103794037
# max supported force 21769.115316438856
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: True
# found viable sub-config
# Tension to begin with is 85000.0
# checking if tower and anchor trees hold
# exerted force 85000.0
# did not find anchor tree that holds - iterating
# exerted force 85000.0
# did not find anchor tree that holds - iterating
# exerted force 85000.0
# found anchor tree that holds
# Tower and anchors hold: True
# After the iterative process it is now 85000.0
# checking if no collisions overall line
# Found no collisions
# Tension to begin with is 85000.0
# checking if tower and anchor trees hold
# exerted force 85000.0
# did not find anchor tree that holds - iterating
# exerted force 85000.0
# did not find anchor tree that holds - iterating
# exerted force 85000.0
# did not find anchor tree that holds - iterating
# Tower and anchors hold: False
# checking if tower and anchor trees hold
# exerted force 75000.0
# did not find anchor tree that holds - iterating
# exerted force 75000.0
# did not find anchor tree that holds - iterating
# exerted force 75000.0
# did not find anchor tree that holds - iterating
# Tower and anchors hold: False
# checking if tower and anchor trees hold
# exerted force 65000.0
# did not find anchor tree that holds - iterating
# exerted force 65000.0
# did not find anchor tree that holds - iterating
# exerted force 65000.0
# did not find anchor tree that holds - iterating
# Tower and anchors hold: False
# checking if tower and anchor trees hold
# exerted force 55000.0
# did not find anchor tree that holds - iterating
# exerted force 55000.0
# did not find anchor tree that holds - iterating
# exerted force 55000.0
# did not find anchor tree that holds - iterating
# Tower and anchors hold: False
# checking if tower and anchor trees hold
# exerted force 45000.0
# did not find anchor tree that holds - iterating
# exerted force 45000.0
# found anchor tree that holds
# Tower and anchors hold: True
# After the iterative process it is now 45000.0
# checking if no collisions overall line
# Found collisions
# Need to find supports
# Setting up support candidates
# raising height to  6
# checking if support withstands tension
# force on support left 6255.2677014061155
# force on support right 6880.000469340095
# max supported force 31824.469715144893
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  7
# checking if support withstands tension
# force on support left 2081.8302351351185
# force on support right 2053.3072481716727
# max supported force 23381.243056024818
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  8
# checking if support withstands tension
# force on support left 5035.288637842191
# force on support right 3259.1109199666657
# max supported force 17901.264214769002
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  9
# checking if support withstands tension
# force on support left 9125.414406600956
# force on support right 6255.6103595090535
# max supported force 14144.208762286618
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  10
# checking if support withstands tension
# force on support left 12977.101373465279
# force on support right 9392.2656182099
# max supported force 11456.809097452162
# Support withstands tension: False
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# segment is infesible
# raising height to  6
# checking if support withstands tension
# force on support left 8979.251130290697
# force on support right 7306.358379228695
# max supported force 339571.2084915763
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  7
# checking if support withstands tension
# force on support left 13459.705083125868
# force on support right 11098.283898582178
# max supported force 249480.88787136218
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  8
# checking if support withstands tension
# force on support left 16888.569541515637
# force on support right 13877.0029540711
# max supported force 191008.80477651168
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: True
# found viable sub-config
# Tension to begin with is 85000.0
# checking if tower and anchor trees hold
# exerted force 85000.0
# did not find anchor tree that holds - iterating
# exerted force 85000.0
# did not find anchor tree that holds - iterating
# exerted force 85000.0
# did not find anchor tree that holds - iterating
# exerted force 85000.0
# did not find anchor tree that holds - iterating
# Tower and anchors hold: False
# checking if tower and anchor trees hold
# exerted force 75000.0
# did not find anchor tree that holds - iterating
# exerted force 75000.0
# did not find anchor tree that holds - iterating
# exerted force 75000.0
# did not find anchor tree that holds - iterating
# exerted force 75000.0
# did not find anchor tree that holds - iterating
# Tower and anchors hold: False
# checking if tower and anchor trees hold
# exerted force 65000.0
# did not find anchor tree that holds - iterating
# exerted force 65000.0
# did not find anchor tree that holds - iterating
# exerted force 65000.0
# did not find anchor tree that holds - iterating
# exerted force 65000.0
# did not find anchor tree that holds - iterating
# Tower and anchors hold: False
# checking if tower and anchor trees hold
# exerted force 55000.0
# found anchor tree that holds
# Tower and anchors hold: True
# After the iterative process it is now 55000.0
# checking if no collisions overall line
# Found collisions
# Need to find supports
# Setting up support candidates
# raising height to  6
# checking if support withstands tension
# force on support left 2231.5755017060505
# force on support right 2685.1778648194722
# max supported force 162073.51443995256
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  7
# checking if support withstands tension
# force on support left 2368.820242259435
# force on support right 1567.9066302374017
# max supported force 119074.41877221005
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  8
# checking if support withstands tension
# force on support left 4819.950670068
# force on support right 3467.7713783103827
# max supported force 91166.35187247331
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  9
# checking if support withstands tension
# force on support left 7318.726029097711
# force on support right 5592.909428544575
# max supported force 72032.67308442335
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  10
# checking if support withstands tension
# force on support left 9768.048999290297
# force on support right 7772.272158286902
# max supported force 58346.465198382924
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: True
# found viable sub-config
# Tension to begin with is 85000.0
# checking if tower and anchor trees hold
# exerted force 85000.0
# did not find anchor tree that holds - iterating
# exerted force 85000.0
# did not find anchor tree that holds - iterating
# exerted force 85000.0
# did not find anchor tree that holds - iterating
# exerted force 85000.0
# did not find anchor tree that holds - iterating
# Tower and anchors hold: False
# checking if tower and anchor trees hold
# exerted force 75000.0
# did not find anchor tree that holds - iterating
# exerted force 75000.0
# did not find anchor tree that holds - iterating
# exerted force 75000.0
# did not find anchor tree that holds - iterating
# exerted force 75000.0
# did not find anchor tree that holds - iterating
# Tower and anchors hold: False
# checking if tower and anchor trees hold
# exerted force 65000.0
# did not find anchor tree that holds - iterating
# exerted force 65000.0
# did not find anchor tree that holds - iterating
# exerted force 65000.0
# did not find anchor tree that holds - iterating
# exerted force 65000.0
# did not find anchor tree that holds - iterating
# Tower and anchors hold: False
# checking if tower and anchor trees hold
# exerted force 55000.0
# found anchor tree that holds
# Tower and anchors hold: True
# After the iterative process it is now 55000.0
# checking if no collisions overall line
# Found collisions
# Need to find supports
# Setting up support candidates
# raising height to  6
# checking if support withstands tension
# force on support left 24256.220866460975
# force on support right 20715.07729634671
# max supported force 169038.89432920673
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  7
# checking if support withstands tension
# force on support left 30210.25559454477
# force on support right 25361.13738054019
# max supported force 124191.84073166209
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: True
# found viable sub-config
# Tension to begin with is 85000.0
# checking if tower and anchor trees hold
# exerted force 85000.0
# did not find anchor tree that holds - iterating
# exerted force 85000.0
# did not find anchor tree that holds - iterating
# exerted force 85000.0
# did not find anchor tree that holds - iterating
# exerted force 85000.0
# did not find anchor tree that holds - iterating
# Tower and anchors hold: False
# checking if tower and anchor trees hold
# exerted force 75000.0
# did not find anchor tree that holds - iterating
# exerted force 75000.0
# did not find anchor tree that holds - iterating
# exerted force 75000.0
# did not find anchor tree that holds - iterating
# exerted force 75000.0
# did not find anchor tree that holds - iterating
# Tower and anchors hold: False
# checking if tower and anchor trees hold
# exerted force 65000.0
# did not find anchor tree that holds - iterating
# exerted force 65000.0
# did not find anchor tree that holds - iterating
# exerted force 65000.0
# did not find anchor tree that holds - iterating
# exerted force 65000.0
# did not find anchor tree that holds - iterating
# Tower and anchors hold: False
# checking if tower and anchor trees hold
# exerted force 55000.0
# found anchor tree that holds
# Tower and anchors hold: True
# After the iterative process it is now 55000.0
# checking if no collisions overall line
# Found collisions
# Need to find supports
# Setting up support candidates
# raising height to  6
# checking if support withstands tension
# force on support left 2787.511816007182
# force on support right 2057.8305972330495
# max supported force 86613.59403246743
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  7
# checking if support withstands tension
# force on support left 6489.086006681763
# force on support right 4948.623095472707
# max supported force 63634.47724834342
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  8
# checking if support withstands tension
# force on support left 9351.626598465946
# force on support right 7287.904195856531
# max supported force 48720.14664326293
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  9
# checking if support withstands tension
# force on support left 12140.903115623221
# force on support right 9687.176340756376
# max supported force 38494.93068109664
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: True
# found viable sub-config
# Tension to begin with is 85000.0
# checking if tower and anchor trees hold
# exerted force 85000.0
# did not find anchor tree that holds - iterating
# exerted force 85000.0
# did not find anchor tree that holds - iterating
# exerted force 85000.0
# did not find anchor tree that holds - iterating
# Tower and anchors hold: False
# checking if tower and anchor trees hold
# exerted force 75000.0
# did not find anchor tree that holds - iterating
# exerted force 75000.0
# did not find anchor tree that holds - iterating
# exerted force 75000.0
# did not find anchor tree that holds - iterating
# Tower and anchors hold: False
# checking if tower and anchor trees hold
# exerted force 65000.0
# did not find anchor tree that holds - iterating
# exerted force 65000.0
# did not find anchor tree that holds - iterating
# exerted force 65000.0
# did not find anchor tree that holds - iterating
# Tower and anchors hold: False
# checking if tower and anchor trees hold
# exerted force 55000.0
# found anchor tree that holds
# Tower and anchors hold: True
# After the iterative process it is now 55000.0
# checking if no collisions overall line
# Found collisions
# Need to find supports
# Setting up support candidates
# raising height to  6
# checking if support withstands tension
# force on support left 3242.363889725453
# force on support right 3023.49203156354
# max supported force 89173.15545245806
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  7
# checking if support withstands tension
# force on support left 5405.33513328083
# force on support right 4309.122592907409
# max supported force 65514.97135282633
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  8
# checking if support withstands tension
# force on support left 7666.200934659816
# force on support right 6079.270588049046
# max supported force 50159.89994200766
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  9
# checking if support withstands tension
# force on support left 10023.873393182806
# force on support right 8067.008204255411
# max supported force 39632.51353442581
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  10
# checking if support withstands tension
# force on support left 12371.080197483954
# force on support right 10152.222529501536
# max supported force 32102.335962884903
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  11
# checking if support withstands tension
# force on support left 14670.734804167712
# force on support right 12289.885675731604
# max supported force 26530.856167673475
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: True
# found viable sub-config
# Tension to begin with is 85000.0
# checking if tower and anchor trees hold
# exerted force 85000.0
# did not find anchor tree that holds - iterating
# exerted force 85000.0
# did not find anchor tree that holds - iterating
# exerted force 85000.0
# did not find anchor tree that holds - iterating
# exerted force 85000.0
# did not find anchor tree that holds - iterating
# Tower and anchors hold: False
# checking if tower and anchor trees hold
# exerted force 75000.0
# did not find anchor tree that holds - iterating
# exerted force 75000.0
# did not find anchor tree that holds - iterating
# exerted force 75000.0
# did not find anchor tree that holds - iterating
# exerted force 75000.0
# did not find anchor tree that holds - iterating
# Tower and anchors hold: False
# checking if tower and anchor trees hold
# exerted force 65000.0
# did not find anchor tree that holds - iterating
# exerted force 65000.0
# did not find anchor tree that holds - iterating
# exerted force 65000.0
# did not find anchor tree that holds - iterating
# exerted force 65000.0
# did not find anchor tree that holds - iterating
# Tower and anchors hold: False
# checking if tower and anchor trees hold
# exerted force 55000.0
# found anchor tree that holds
# Tower and anchors hold: True
# After the iterative process it is now 55000.0
# checking if no collisions overall line
# Found collisions
# Need to find supports
# Setting up support candidates
# raising height to  6
# checking if support withstands tension
# force on support left 1998.8378342382898
# force on support right 2377.0952171110666
# max supported force 89173.15545245806
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  7
# checking if support withstands tension
# force on support left 3186.6262829550747
# force on support right 2231.233062179218
# max supported force 65514.97135282633
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  8
# checking if support withstands tension
# force on support left 5491.110219110359
# force on support right 4032.472459723057
# max supported force 50159.89994200766
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  9
# checking if support withstands tension
# force on support left 7858.410665017427
# force on support right 6056.031208428756
# max supported force 39632.51353442581
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  10
# checking if support withstands tension
# force on support left 10193.605667081147
# force on support right 8149.7926495624515
# max supported force 32102.335962884903
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: True
# found viable sub-config
# Tension to begin with is 85000.0
# checking if tower and anchor trees hold
# exerted force 85000.0
# did not find anchor tree that holds - iterating
# exerted force 85000.0
# did not find anchor tree that holds - iterating
# exerted force 85000.0
# did not find anchor tree that holds - iterating
# Tower and anchors hold: False
# checking if tower and anchor trees hold
# exerted force 75000.0
# did not find anchor tree that holds - iterating
# exerted force 75000.0
# did not find anchor tree that holds - iterating
# exerted force 75000.0
# did not find anchor tree that holds - iterating
# Tower and anchors hold: False
# checking if tower and anchor trees hold
# exerted force 65000.0
# did not find anchor tree that holds - iterating
# exerted force 65000.0
# did not find anchor tree that holds - iterating
# exerted force 65000.0
# did not find anchor tree that holds - iterating
# Tower and anchors hold: False
# checking if tower and anchor trees hold
# exerted force 55000.0
# found anchor tree that holds
# Tower and anchors hold: True
# After the iterative process it is now 55000.0
# checking if no collisions overall line
# Found collisions
# Need to find supports
# Setting up support candidates
# raising height to  6
# checking if support withstands tension
# force on support left 3242.363889725453
# force on support right 3023.49203156354
# max supported force 89173.15545245806
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  7
# checking if support withstands tension
# force on support left 5405.33513328083
# force on support right 4309.122592907409
# max supported force 65514.97135282633
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  8
# checking if support withstands tension
# force on support left 7666.200934659816
# force on support right 6079.270588049046
# max supported force 50159.89994200766
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  9
# checking if support withstands tension
# force on support left 10023.873393182806
# force on support right 8067.008204255411
# max supported force 39632.51353442581
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  10
# checking if support withstands tension
# force on support left 12371.080197483954
# force on support right 10152.222529501536
# max supported force 32102.335962884903
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  11
# checking if support withstands tension
# force on support left 14670.734804167712
# force on support right 12289.885675731604
# max supported force 26530.856167673475
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: True
# found viable sub-config
# Tension to begin with is 85000.0
# checking if tower and anchor trees hold
# exerted force 85000.0
# did not find anchor tree that holds - iterating
# exerted force 85000.0
# did not find anchor tree that holds - iterating
# exerted force 85000.0
# did not find anchor tree that holds - iterating
# Tower and anchors hold: False
# checking if tower and anchor trees hold
# exerted force 75000.0
# did not find anchor tree that holds - iterating
# exerted force 75000.0
# did not find anchor tree that holds - iterating
# exerted force 75000.0
# did not find anchor tree that holds - iterating
# Tower and anchors hold: False
# checking if tower and anchor trees hold
# exerted force 65000.0
# did not find anchor tree that holds - iterating
# exerted force 65000.0
# did not find anchor tree that holds - iterating
# exerted force 65000.0
# did not find anchor tree that holds - iterating
# Tower and anchors hold: False
# checking if tower and anchor trees hold
# exerted force 55000.0
# found anchor tree that holds
# Tower and anchors hold: True
# After the iterative process it is now 55000.0
# checking if no collisions overall line
# Found collisions
# Need to find supports
# Setting up support candidates
# raising height to  6
# checking if support withstands tension
# force on support left 3242.363889725453
# force on support right 3023.49203156354
# max supported force 89173.15545245806
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  7
# checking if support withstands tension
# force on support left 5405.33513328083
# force on support right 4309.122592907409
# max supported force 65514.97135282633
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# ...
# raising height to  11
# checking if support withstands tension
# force on support left 10761.602090984856
# force on support right 9672.273536575296
# max supported force 36956.236066847436
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  12
# checking if support withstands tension
# force on support left 12824.740513895546
# force on support right 12231.076292769474
# max supported force 31053.503917281527
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  13
# checking if support withstands tension
# force on support left 14858.858002183106
# force on support right 14862.669362476663
# max supported force 26459.79032005053
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  14
# checking if support withstands tension
# force on support left 16858.986720078738
# force on support right 17556.379554638926
# max supported force 22814.819204533367
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# segment is infesible
# raising height to  6
# checking if support withstands tension
# force on support left 11191.182844036215
# force on support right 9264.389749953605
# max supported force 169038.89432920673
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  7
# checking if support withstands tension
# force on support left 16875.83628472008
# force on support right 13998.257715111198
# max supported force 124191.84073166209
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: True
# found viable sub-config
# Tension to begin with is 85000.0
# checking if tower and anchor trees hold
# exerted force 85000.0
# did not find anchor tree that holds - iterating
# exerted force 85000.0
# did not find anchor tree that holds - iterating
# exerted force 85000.0
# did not find anchor tree that holds - iterating
# exerted force 85000.0
# did not find anchor tree that holds - iterating
# Tower and anchors hold: False
# checking if tower and anchor trees hold
# exerted force 75000.0
# did not find anchor tree that holds - iterating
# exerted force 75000.0
# did not find anchor tree that holds - iterating
# exerted force 75000.0
# did not find anchor tree that holds - iterating
# exerted force 75000.0
# did not find anchor tree that holds - iterating
# Tower and anchors hold: False
# checking if tower and anchor trees hold
# exerted force 65000.0
# did not find anchor tree that holds - iterating
# exerted force 65000.0
# did not find anchor tree that holds - iterating
# exerted force 65000.0
# did not find anchor tree that holds - iterating
# exerted force 65000.0
# did not find anchor tree that holds - iterating
# Tower and anchors hold: False
# checking if tower and anchor trees hold
# exerted force 55000.0
# found anchor tree that holds
# Tower and anchors hold: True
# After the iterative process it is now 55000.0
# checking if no collisions overall line
# Found collisions
# Need to find supports
# Setting up support candidates
# raising height to  6
# checking if support withstands tension
# force on support left 9787.210448719788
# force on support right 8312.507559252366
# max supported force 2165.961296676192
# Support withstands tension: False
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# segment is infesible
# raising height to  6
# checking if support withstands tension
# force on support left 10329.642177662443
# force on support right 8805.004132614325
# max supported force 91625.80733099408
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  7
# checking if support withstands tension
# force on support left 14739.32985821192
# force on support right 12849.00115680702
# max supported force 67316.91967175074
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: True
# found viable sub-config
# Tension to begin with is 85000.0
# checking if tower and anchor trees hold
# exerted force 85000.0
# did not find anchor tree that holds - iterating
# exerted force 85000.0
# did not find anchor tree that holds - iterating
# exerted force 85000.0
# did not find anchor tree that holds - iterating
# Tower and anchors hold: False
# checking if tower and anchor trees hold
# exerted force 75000.0
# did not find anchor tree that holds - iterating
# exerted force 75000.0
# did not find anchor tree that holds - iterating
# exerted force 75000.0
# did not find anchor tree that holds - iterating
# Tower and anchors hold: False
# checking if tower and anchor trees hold
# exerted force 65000.0
# did not find anchor tree that holds - iterating
# exerted force 65000.0
# did not find anchor tree that holds - iterating
# exerted force 65000.0
# did not find anchor tree that holds - iterating
# Tower and anchors hold: False
# checking if tower and anchor trees hold
# exerted force 55000.0
# found anchor tree that holds
# Tower and anchors hold: True
# After the iterative process it is now 55000.0
# checking if no collisions overall line
# Found collisions
# Need to find supports
# Setting up support candidates
# raising height to  6
# checking if support withstands tension
# force on support left 10082.246662283595
# force on support right 10209.807315220722
# max supported force 2995.8128173531018
# Support withstands tension: False
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# segment is infesible
# raising height to  6
# checking if support withstands tension
# force on support left 9832.36426629137
# force on support right 10021.16121411809
# max supported force 203392.00581198055
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  7
# checking if support withstands tension
# force on support left 5363.054218920449
# force on support right 5334.458268862176
# max supported force 149430.86141288365
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  8
# checking if support withstands tension
# force on support left 2160.5224100483238
# force on support right 3039.4702817421603
# max supported force 114408.00326923905
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  9
# checking if support withstands tension
# force on support left 2152.655820392722
# force on support right 1308.837680163369
# max supported force 90396.4470275469
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  10
# checking if support withstands tension
# force on support left 5093.881363037902
# force on support right 2430.0510355350652
# max supported force 73221.12209231299
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  11
# checking if support withstands tension
# force on support left 8115.176043139421
# force on support right 4667.604622220996
# max supported force 60513.32404323388
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  12
# checking if support withstands tension
# force on support left 11031.23271735126
# force on support right 7019.396615315332
# max supported force 50848.00145299514
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: True
# found viable sub-config
# Tension to begin with is 85000.0
# checking if tower and anchor trees hold
# exerted force 85000.0
# did not find anchor tree that holds - iterating
# exerted force 85000.0
# did not find anchor tree that holds - iterating
# exerted force 85000.0
# did not find anchor tree that holds - iterating
# Tower and anchors hold: False
# checking if tower and anchor trees hold
# exerted force 75000.0
# did not find anchor tree that holds - iterating
# exerted force 75000.0
# did not find anchor tree that holds - iterating
# exerted force 75000.0
# did not find anchor tree that holds - iterating
# Tower and anchors hold: False
# checking if tower and anchor trees hold
# exerted force 65000.0
# did not find anchor tree that holds - iterating
# exerted force 65000.0
# did not find anchor tree that holds - iterating
# exerted force 65000.0
# did not find anchor tree that holds - iterating
# Tower and anchors hold: False
# checking if tower and anchor trees hold
# exerted force 55000.0
# found anchor tree that holds
# Tower and anchors hold: True
# After the iterative process it is now 55000.0
# checking if no collisions overall line
# Found collisions
# Need to find supports
# Setting up support candidates
# raising height to  6
# checking if support withstands tension
# force on support left 10429.809035750608
# force on support right 8708.105427517998
# max supported force 48182.46997685301
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: True
# found viable sub-config
# Tension to begin with is 85000.0
# checking if tower and anchor trees hold
# exerted force 85000.0
# did not find anchor tree that holds - iterating
# exerted force 85000.0
# did not find anchor tree that holds - iterating
# exerted force 85000.0
# did not find anchor tree that holds - iterating
# Tower and anchors hold: False
# checking if tower and anchor trees hold
# exerted force 75000.0
# did not find anchor tree that holds - iterating
# exerted force 75000.0
# found anchor tree that holds
# Tower and anchors hold: True
# After the iterative process it is now 75000.0
# checking if no collisions overall line
# Found no collisions
# Tension to begin with is 85000.0
# checking if tower and anchor trees hold
# exerted force 85000.0
# did not find anchor tree that holds - iterating
# exerted force 85000.0
# did not find anchor tree that holds - iterating
# exerted force 85000.0
# did not find anchor tree that holds - iterating
# Tower and anchors hold: False
# checking if tower and anchor trees hold
# exerted force 75000.0
# did not find anchor tree that holds - iterating
# exerted force 75000.0
# found anchor tree that holds
# Tower and anchors hold: True
# After the iterative process it is now 75000.0
# checking if no collisions overall line
# Found no collisions
# Tension to begin with is 85000.0
# checking if tower and anchor trees hold
# exerted force 85000.0
# did not find anchor tree that holds - iterating
# exerted force 85000.0
# did not find anchor tree that holds - iterating
# exerted force 85000.0
# did not find anchor tree that holds - iterating
# Tower and anchors hold: False
# checking if tower and anchor trees hold
# exerted force 75000.0
# did not find anchor tree that holds - iterating
# exerted force 75000.0
# found anchor tree that holds
# Tower and anchors hold: True
# After the iterative process it is now 75000.0
# checking if no collisions overall line
# Found no collisions
# Tension to begin with is 85000.0
# checking if tower and anchor trees hold
# exerted force 85000.0
# did not find anchor tree that holds - iterating
# exerted force 85000.0
# did not find anchor tree that holds - iterating
# exerted force 85000.0
# did not find anchor tree that holds - iterating
# Tower and anchors hold: False
# checking if tower and anchor trees hold
# exerted force 75000.0
# did not find anchor tree that holds - iterating
# exerted force 75000.0
# found anchor tree that holds
# Tower and anchors hold: True
# After the iterative process it is now 75000.0
# checking if no collisions overall line
# Found collisions
# Need to find supports
# Setting up support candidates
# raising height to  6
# checking if support withstands tension
# force on support left 2709.8040735121626
# force on support right 2255.4182838503334
# max supported force 1700.6645640285274
# Support withstands tension: False
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# segment is infesible
# raising height to  6
# checking if support withstands tension
# force on support left 51214.18072549139
# force on support right 50368.0389805423
# max supported force 213681.8243129388
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  7
# checking if support withstands tension
# force on support left 48128.442685527116
# force on support right 44868.37229595723
# max supported force 156990.72806664894
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  8
# checking if support withstands tension
# force on support left 53520.07512036737
# force on support right 48902.74491268875
# max supported force 120196.02617602808
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: False
# iterating through height series since we have collisions
# raising height to  9
# checking if support withstands tension
# force on support left 59093.858037683654
# force on support right 54068.03227611994
# max supported force 94969.69969463948
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: True
# found viable sub-config
# Tension to begin with is 85000.0
# checking if tower and anchor trees hold
# exerted force 85000.0
# did not find anchor tree that holds - iterating
# exerted force 85000.0
# did not find anchor tree that holds - iterating
# exerted force 85000.0
# did not find anchor tree that holds - iterating
# Tower and anchors hold: False
# checking if tower and anchor trees hold
# exerted force 75000.0
# did not find anchor tree that holds - iterating
# exerted force 75000.0
# found anchor tree that holds
# Tower and anchors hold: True
# After the iterative process it is now 75000.0
# checking if no collisions overall line
# Found collisions
# Need to find supports
# Setting up support candidates
# raising height to  6
# checking if support withstands tension
# force on support left 13116.983322200886
# force on support right 11770.403976560176
# max supported force 48182.46997685301
# Support withstands tension: True
# checking if no collisions overall line
# checking if no collisions overall line
# No collisions: True
# found viable sub-config
# 38  after checking for height obstructions
# we have n lines:  38
# Starting basis optimization
# Starting with objective 0
# Starting with objective 1
# Starting with objective 2
# Starting manual weights optimization
# c:\alles\uni\2025SS\BachelorArbeit\codexBachi\.venv\lib\site-packages\pulp\pulp.py:1704: UserWarning:
#
# Overwriting previously set objective.
# Starting NSGA II optimization
# c:\alles\uni\2025SS\BachelorArbeit\codexBachi\src\main\classes_mo_optimization.py:425: RuntimeWarning:
#
# overflow encountered in exp
# Profit baseline is 26901.212385330604
# Profit baseline is 26901.21238533062

# %% [markdown]
# #### Plotting

# %%
# from src.main.frontend.interface import build_interface

# display(build_interface(forest_area_3, model_list, results_df))

import warnings

from src.main.frontend.table import Table

from src.main.frontend.data_prep import build_viz_data
from src.main.frontend.radar_chart import build_radar_dashboard
from src.main.frontend.interface import build_interface

warnings.filterwarnings("ignore", message=".*The 'nopython' keyword.*")

# Package Imports
import pandas as pd
import geopandas as gpd
from shapely.geometry import LineString, Polygon, Point
import pickle


# Interface modules
from ipywidgets import VBox, HBox
from src.main.interface import interactive_cr_selection
from src.main.results_io import load_viz, load_results, save_results, save_results_for_humans

# save_results(forest_area_3,"forest_area_3_cashed.txt")
# save_results( model_list, "model_list_cached.txt")
# save_results(results_df, "results_df_cached.txt")


forest_area_3 = load_results("forest_area_3_cashed.txt")
model_list = load_results("model_list_cached.txt")
results_df = load_results("results_df_cached.txt")

display(build_interface(forest_area_3, model_list, results_df))
# Out:
# VBox(children=(HBox(children=(HTML(value='<style>.border-radius, .border-radius { border-radius: 12px !importa…
